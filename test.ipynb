# %%
import numpy as np
from pathlib import Path
from make_plots import start
import os
import sys
import torch
import argparse
import numpy as np
from plots import *
import pandas as pd
import models as models
from pathlib import Path
from preprocess_data import *
from sklearn.metrics import r2_score
from process_session import session as ps
from scipy.sparse import coo_matrix, save_npz

# %%
output_dir = Path('E:/jerry/vbn_s3_cache/')
session_id = 1044385384

# %%
df = pd.read_csv('./units_info.csv')
session_obj = ps(session_id, df, output_dir)

input_size = len(session_obj.units)
hidden_size = 50 
num_layers = 1
seqlength = 750
num_epochs = 15
bands = [(0.5, 4), (4, 8), (8, 12), (12, 25), (25, 50), (50, 100), (100, 200), (200, 400)]
criterion  = torch.nn.MSELoss()
batch_size = 32
bin_size=0.004

spikes_obj = pre_process_spikes(session_obj.units, session_obj.spike_times, bin_size=bin_size, sigma=3)
spikes_obj.getSpkMat(session_obj.active_times[0], session_obj.active_times[1])
spikes_obj.truncate(seqlength)
spikes_obj.minmax()

# %%
dir(spikes_obj)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'bin_size',
#  'convolve_with_gaussian',
#  'getSpkMat',
#  'minmax',
#  'sigma',
#  'spike_times',
#  'spkMat',
#  'timestamps',
#  'truncate',
#  'units',
#  'zscore']

# %%
spikes = spikes_obj.spkMat

# %%
from scipy.sparse import coo_matrix, save_npz
spk_mat = coo_matrix(spikes)
save_npz('spk_mat.npz', spk_mat)
